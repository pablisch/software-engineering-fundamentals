# %% [markdown]
# # SEF session 2
#
# - Jonty Beglin
# - Noor Amini
# - Juwairiya Qureshi
# - Taslimah Rahman

# %%
# --------- Part 1 ----------

stock = {
    "Soda" : 3,
    "Chips" : 10,
    "Candy" : 10
}

def check_stock(item: str) -> bool:
  if stock[item] <= 0:
    return False
  return True

# %%
# --------- Part 2 ----------
prices = {
    "Soda" : 1.25,
    "Chips" : 1.50,
    "Candy" : 2.00
}

def get_money(item: str) -> int:
  total = 0
  while prices[item] > total:
    total += float(input("Enter Money: "))
  stock[item] -= 1
  return total - prices[item]

# %%
# --------- Part 3 ----------

def update_stock():
  for item in stock.keys():
    if stock[item] < 2:
      print(f"{item} needs to be restocked")

# %%
# --------- Final ----------
def loop():
  product = input("What you want? ")
  if product not in stock.keys():
    print("Invalid item")
    return
  if not check_stock(product):
    print("Out of stock")
    return
  print(f"£{get_money(product)} change")
  update_stock()

while True:
  loop()
# Out:
# Invalid item
# £8.75 change
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      11   update_stock()
#      13 while True:
# ---> 14   loop()
#
# Cell In[4], line 3, in loop()
#       2 def loop():
# ----> 3   product = input("What you want? ")
#       4   if product not in stock.keys():
#       5     print("Invalid item")
#
# File ~/pablisch/bpp/softwareEng/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# ...
