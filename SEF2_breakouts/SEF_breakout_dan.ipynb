# %%
Ben
Dan
Talha

# %%
prices = {"soda": 1.00, "chips": 1.50, "candy": 0.50}
coins = 0
price = prices[user_request]

while (coins <= price)
    amount = float(input("Enter coins input:"))
    coins += amount
